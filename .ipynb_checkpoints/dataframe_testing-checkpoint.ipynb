# %% [markdown]
# # EY Data Science Competition

# %% [markdown]
# ## Initial data wrangling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('EY-data-science-challenge-pack/train.csv')

df
# Out:
#         id LOCATION  TIME GENDER  Population (% of total)  \
# 0        1      AUS  1993    MEN                49.780616
# 1        2      AUS  1993  WOMEN                50.219384
# 2        3      AUS  1994    MEN                49.762137
# 3        4      AUS  1994  WOMEN                50.237863
# 4        5      AUS  1995    MEN                49.758261
# 5        6      AUS  1995  WOMEN                50.241739
# 6        7      AUS  1997    MEN                49.798905
# 7        8      AUS  1997  WOMEN                50.201095
# 8        9      AUS  1998    MEN                49.833357
# 9       10      AUS  1998  WOMEN                50.166643
# 10      11      AUS  1999    MEN                49.865151
# 11      12      AUS  1999  WOMEN                50.134849
# 12      13      AUS  2000    MEN                49.887776
# 13      14      AUS  2000  WOMEN                50.112224
# 14      15      AUS  2001    MEN                49.898204
# 15      16      AUS  2001  WOMEN                50.101796
# 16      17      AUS  2002    MEN                49.899059
# 17      18      AUS  2002  WOMEN                50.100941
# 18      19      AUS  2003    MEN                49.896017
# 19      20      AUS  2003  WOMEN                50.103983
# 20      21      AUS  2004    MEN                49.897245
# 21      22      AUS  2004  WOMEN                50.102755
# 22      23      AUS  2005    MEN                49.907665
# 23      24      AUS  2005  WOMEN                50.092335
# 24      25      AUS  2006    MEN                49.929633
# 25      26      AUS  2006  WOMEN                50.070367
# 26      27      AUS  2007    MEN                49.959301
# 27      28      AUS  2007  WOMEN                50.040699
# 28      29      AUS  2008    MEN                49.988350
# 29      30      AUS  2008  WOMEN                50.011650
# ...    ...      ...   ...    ...                      ...
# 980   1175      TUR  2010    MEN                49.171457
# 981   1176      TUR  2010  WOMEN                50.828543
# 982   1177      TUR  2011    MEN                49.167300
# 983   1178      TUR  2011  WOMEN                50.832700
# 984   1179      TUR  2012    MEN                49.164991
# 985   1180      TUR  2012  WOMEN                50.835009
# 986   1181      TUR  2013    MEN                49.166736
# 987   1182      TUR  2013  WOMEN                50.833264
# 988   1183      TUR  2014    MEN                49.175250
# 989   1184      TUR  2014  WOMEN                50.824750
# 990   1185      TUR  2015    MEN                49.191727
# 991   1186      TUR  2015  WOMEN                50.808273
# 992   1187      TUR  2016    MEN                49.217503
# 993   1188      TUR  2016  WOMEN                50.782497
# 994   1237      ZAF  2008    MEN                49.093185
# 995   1238      ZAF  2008  WOMEN                50.906815
# 996   1239      ZAF  2009    MEN                49.097932
# 997   1240      ZAF  2009  WOMEN                50.902068
# 998   1241      ZAF  2010    MEN                49.102184
# 999   1242      ZAF  2010  WOMEN                50.897816
# 1000  1243      ZAF  2011    MEN                49.106008
# 1001  1244      ZAF  2011  WOMEN                50.893992
# 1002  1245      ZAF  2012    MEN                49.109108
# 1003  1246      ZAF  2012  WOMEN                50.890892
# 1004  1247      ZAF  2013    MEN                49.110337
# 1005  1248      ZAF  2013  WOMEN                50.889663
# 1006  1249      ZAF  2014    MEN                49.108363
# 1007  1250      ZAF  2014  WOMEN                50.891637
# 1008  1251      ZAF  2015    MEN                49.102396
# 1009  1252      ZAF  2015  WOMEN                50.897604
#
# 1009               12.543431    4.509208  13282.00987            NaN
#
#       %_Sanitation_Access           ...             \
# 0                   100.0           ...
# 1                   100.0           ...
# 2                   100.0           ...
# 3                   100.0           ...
# 4                   100.0           ...
# 5                   100.0           ...
# 6                   100.0           ...
# 7                   100.0           ...
# 8                   100.0           ...
# 9                   100.0           ...
# 10                  100.0           ...
# 11                  100.0           ...
# 12                  100.0           ...
# 13                  100.0           ...
# 14                  100.0           ...
# 15                  100.0           ...
# 16                  100.0           ...
# 17                  100.0           ...
# 18                  100.0           ...
# 19                  100.0           ...
# 20                  100.0           ...
# 21                  100.0           ...
# 22                  100.0           ...
# 23                  100.0           ...
# 24                  100.0           ...
# 25                  100.0           ...
# 26                  100.0           ...
# 27                  100.0           ...
# 28                  100.0           ...
# 29                  100.0           ...
# ...                   ...           ...
# 980                  92.9           ...
# 981                  92.9           ...
# 982                  93.3           ...
# 983                  93.3           ...
# 984                  93.7           ...
# 985                  93.7           ...
# 986                  94.1           ...
# 987                  94.1           ...
# 988                  94.5           ...
# 989                  94.5           ...
# 990                  94.9           ...
# 991                  94.9           ...
# 992                   NaN           ...
# 993                   NaN           ...
# 994                  62.3           ...
# 995                  62.3           ...
# 996                  62.9           ...
# 997                  62.9           ...
# 998                  63.5           ...
# 999                  63.5           ...
# 1000                 64.1           ...
# 1001                 64.1           ...
# 1002                 64.7           ...
# 1003                 64.7           ...
# 1004                 65.3           ...
# 1005                 65.3           ...
# 1006                 65.8           ...
# 1007                 65.8           ...
# 1008                 66.4           ...
# 1009                 66.4           ...
#
#       Population ages 50-54 (as % of specified gender population)  \
# 0                                              5.125739
# 1                                              4.874607
# 2                                              5.260645
# 3                                              5.003437
# 4                                              5.448858
# 5                                              5.185767
# 6                                              5.971580
# 7                                              5.701808
# 8                                              6.298525
# 9                                              6.021525
# 10                                             6.585599
# 11                                             6.310521
# 12                                             6.778976
# 13                                             6.524799
# 14                                             6.828922
# 15                                             6.630671
# 16                                             6.779401
# 17                                             6.652137
# 18                                             6.674164
# 19                                             6.620005
# 20                                             6.579411
# 21                                             6.584250
# 22                                             6.533655
# 23                                             6.575971
# 24                                             6.487497
# 25                                             6.558892
# 26                                             6.481459
# 27                                             6.565718
# 28                                             6.509294
# 29                                             6.592276
# ...                                                 ...
# 980                                            4.656380
# 981                                            5.140010
# 982                                            4.751142
# 983                                            5.195031
# 984                                            4.847834
# 985                                            5.247349
# 986                                            4.941982
# 987                                            5.296002
# 988                                            5.031826
# 989                                            5.343222
# 990                                            5.118677
# 991                                            5.392723
# 992                                            5.211232
# 993                                            5.449258
# 994                                            3.932228
# 995                                            4.380757
# 996                                            3.929534
# 997                                            4.401485
# 998                                            3.926887
# 999                                            4.424347
# 1000                                           3.956613
# 1001                                           4.462673
# 1002                                           3.990325
# 1003                                           4.503148
# 1004                                           4.025086
# 1005                                           4.544222
# 1006                                           4.059090
# 1007                                           4.584548
# 1008                                           4.093348
# 1009                                           4.624192
#
#       Population ages 55-59 (as % of specified gender population)  \
# 0                                              4.363110
# 1                                              4.220368
# 2                                              4.417681
# 3                                              4.267955
# 4                                              4.480351
# 5                                              4.322439
# 6                                              4.645555
# 7                                              4.462526
# 8                                              4.734440
# 9                                              4.545056
# 10                                             4.857964
# 11                                             4.665021
# 12                                             5.040022
# 13                                             4.842062
# 14                                             5.267482
# 15                                             5.076135
# 16                                             5.557414
# 17                                             5.365802
# 18                                             5.860062
# 19                                             5.667737
# 20                                             6.102383
# 21                                             5.919539
# 22                                             6.243142
# 23                                             6.085398
# 24                                             6.255894
# 25                                             6.138013
# 26                                             6.174678
# 27                                             6.112401
# 28                                             6.042988
# 29                                             6.042534
# ...                                                 ...
# 980                                            3.812436
# 981                                            4.403989
# 982                                            3.891416
# 983                                            4.495478
# 984                                            3.972117
# 985                                            4.570047
# 986                                            4.058839
# 987                                            4.635686
# 988                                            4.154297
# 989                                            4.701171
# 990                                            4.256936
# 991                                            4.769288
# 992                                            4.334036
# 993                                            4.816675
# 994                                            3.072372
# 995                                            3.502305
# 996                                            3.153485
# 997                                            3.623083
# 998                                            3.209983
# 999                                            3.715161
# 1000                                           3.257091
# 1001                                           3.788558
# 1002                                           3.291696
# 1003                                           3.841073
# 1004                                           3.319990
# 1005                                           3.880832
# 1006                                           3.350396
# 1007                                           3.919829
# 1008                                           3.386542
# 1009                                           3.964411
#
#       Population ages 60-64 (as % of specified gender population)  \
# 0                                              4.022097
# 1                                              4.009922
# 2                                              3.955058
# 3                                              3.941137
# 4                                              3.926157
# 5                                              3.906003
# 6                                              3.939397
# 7                                              3.889003
# 8                                              4.001133
# 9                                              3.931565
# 10                                             4.081213
# 11                                             3.992263
# 12                                             4.164758
# 13                                             4.058531
# 14                                             4.213112
# 15                                             4.111839
# 16                                             4.254822
# 17                                             4.164060
# 18                                             4.311650
# 19                                             4.233595
# 20                                             4.415586
# 21                                             4.347698
# 22                                             4.579674
# 23                                             4.516707
# 24                                             4.771061
# 25                                             4.706870
# 26                                             5.011675
# 27                                             4.938315
# 28                                             5.254678
# 29                                             5.170121
# ...                                                 ...
# 980                                            2.949731
# 981                                            3.336016
# 982                                            3.013209
# 983                                            3.451481
# 984                                            3.090398
# 985                                            3.587882
# 986                                            3.175742
# 987                                            3.731456
# 988                                            3.264828
# 989                                            3.865642
# 990                                            3.357650
# 991                                            3.983556
# 992                                            3.434798
# 993                                            4.078426
# 994                                            2.204516
# 995                                            2.606042
# 996                                            2.227218
# 997                                            2.639301
# 998                                            2.273167
# 999                                            2.703166
# 1000                                           2.333119
# 1001                                           2.793824
# 1002                                           2.413506
# 1003                                           2.911888
# 1004                                           2.503406
# 1005                                           3.041059
# 1006                                           2.587952
# 1007                                           3.160046
# 1008                                           2.659529
# 1009                                           3.257892
#
#      Population ages 65-69 (as % of specified gender population)  \
# 0                                              3.744820
# 1                                              3.997684
# 2                                              3.738131
# 3                                              3.942406
# 4                                              3.716121
# 5                                              3.882738
# 6                                              3.617378
# 7                                              3.729181
# 8                                              3.554846
# 9                                              3.651983
# 10                                             3.509158
# 11                                             3.591766
# 12                                             3.496295
# 13                                             3.559710
# 14                                             3.491359
# 15                                             3.543207
# 982            65.919327                                       11230
# 983            55.421890                                       11230
# 984            74.778450                                       11880
# 985            63.700878                                       11880
# 986            84.914482                                       12530
# 987            72.904732                                       12530
# 988            92.319267                                       12590
# 989            80.142151                                       12590
# 990           101.013168                                       12000
# 991            88.277168                                       12000
# 992                  NaN                                       11230
# 993                  NaN                                       11230
# 994                  NaN                                        5910
# 995                  NaN                                        5910
# 996                  NaN                                        5800
# 997                  NaN                                        5800
# 998                  NaN                                        6160
# 999                  NaN                                        6160
# 1000                 NaN                                        6970
# 1001                 NaN                                        6970
# 1002           15.540310                                        7540
# 1003           22.633619                                        7540
# 1004           16.011080                                        7340
# 1005           23.526510                                        7340
# 1006           15.700690                                        6750
# 1007           23.307810                                        6750
# 1008                 NaN                                        6070
# 1009                 NaN                                        6070
#
#       Quality_of_life_measure
# 0                    0.172055
# 1                    0.238161
# 2                    0.173419
# 3                    0.239558
# 4                    0.173718
# 5                    0.238771
# 6                    0.175278
# 7                    0.239344
# 8                    0.174626
# 9                    0.237625
# 10                   0.176441
# 11                   0.239491
# 12                   0.181307
# 13                   0.242175
# 14                   0.189981
# 15                   0.250892
# 16                   0.189997
# 17                   0.248650
# 18                   0.198652
# 19                   0.255075
# 20                   0.201534
# 21                   0.256824
# 22                   0.205462
# 23                   0.259618
# 24                   0.204586
# 25                   0.258723
# 26                   0.207182
# 27                   0.260143
# 28                   0.208134
# 29                   0.258795
# ...                       ...
# 980                  0.489610
# 981                  0.373690
# 982                  0.503308
# 983                  0.382215
# 984                  0.506056
# 985                  0.388660
# 986                  0.511640
# 987                  0.396632
# 988                  0.513505
# 989                  0.396886
# 990                  0.518824
# 991                  0.404871
# 992                  0.518578
# 993                  0.406876
# 994                  0.165500
# 995                  0.150514
# 996                  0.160374
# 997                  0.157514
# 998                  0.167066
# 999                  0.168578
# 1000                 0.180099
# 1001                 0.188399
# 1002                 0.195383
# 1003                 0.208149
# 1004                 0.209561
# 1005                 0.229971
# 1006                 0.219622
# 1007                 0.241271
# 1008                 0.245091
# 1009                 0.266682
#
# [1010 rows x 41 columns]

# %% [markdown]
# #### I'm going to use only male stats for the time being for simplicity

# %%
df_male = df.loc[df['GENDER'] == 'MEN']

# %% [markdown]
# ## TimeSeries Experimentation for AUS

# %%
df_country = df_male.loc[df_male['LOCATION'] == 'AUS']
#print(france)

# %% [markdown]
# ### Tertiary Education Timeseries

# %%
fig, ax = plt.subplots(1,1)
gdp = ax.plot(df_country['TIME'],df_country['EDU_TERTIARY_PC_WKGPOP'],'b')
ax2 = ax.twinx()
gni = ax2.plot(df_country['TIME'],df_country['TER_Enrolment_rate'],'g')

plt.plot()
plt.legend()

# %% [markdown]
# ### GNI, GDP Timeseries

# %%
fig, ax = plt.subplots(1,1)
ax2 = ax.twinx()
gdp = ax2.plot(df_country['TIME'],df_country['GDP_USD_CAP'],'b')
ax3 = ax.twinx()
gni = ax3.plot(df_country['TIME'],df_country['GNI per capita, Atlas method (current US$)'],'g')

plt.plot()
plt.legend()

# %%
fig, ax = plt.subplots(1,1)
#cpi = ax.plot(FRA['TIME'],FRA['CPI_AGRWTH'],'r')
#ax = ax.twinx()
gdp = ax.plot(df_country['TIME'],df_country['GOV_SPEND_EDU'],'b')
#ax3 = ax.twinx()
#gni = ax3.plot(FRA['TIME'],FRA['TER_Enrolment_rate'],'g')

plt.plot()
plt.legend()

# %% [markdown]
# ## Comparing GDP across nations

# %%
df_2016 = df_male.loc[df_male['TIME'] == 2016] # 2016 has 54 rows and other years seem to all have 60
df_2016
# Out:
#        id LOCATION  TIME GENDER  Population (% of total)  \
# 44     45      AUS  2016    MEN                49.823542
# 80     81      AUT  2016    MEN                48.994621
# 116   117      BEL  2016    MEN                49.221931
# 160   161      CAN  2016    MEN                49.608846
# 202   227      COL  2016    MEN                49.215490
# 240   265      CZE  2016    MEN                49.144544
# 264   289      DEU  2016    MEN                49.213522
# 300   325      DNK  2016    MEN                49.735157
# 336   361      ESP  2016    MEN                49.040702
# 370   395      EST  2016    MEN                46.813100
# 408   433      FIN  2016    MEN                49.244912
# 442   493      GBR  2016    MEN                49.314320
# 478   567      HUN  2016    MEN                47.550044
# 538   627      ISL  2016    MEN                50.164525
# 582   671      ISR  2016    MEN                49.633244
# 620   709      ITA  2016    MEN                48.702126
# 668   757      JPN  2016    MEN                48.846509
# 702   791      KOR  2016    MEN                50.046245
# 730   819      LUX  2016    MEN                50.233873
# 760   849      LVA  2016    MEN                45.913629
# 794   907      NLD  2016    MEN                49.731462
# 828  1023      POL  2016    MEN                48.298256
# 866  1061      PRT  2016    MEN                47.337853
# 902  1097      SVK  2016    MEN                48.611492
# 938  1133      SVN  2016    MEN                49.631929
# 970  1165      SWE  2016    MEN                50.013332
# 992  1187      TUR  2016    MEN                49.217503
#
#      EDU_TERTIARY_PC_WKGPOP  CPI_AGRWTH   GDP_USD_CAP  GOV_SPEND_EDU  \
# 44                39.767620    1.276991   48177.78556            NaN
# 80                32.170181    0.891592   50503.32841            NaN
# 116               34.192955    1.973853   46607.39577            NaN
# 160               50.077358    1.428760   44792.54562            NaN
# 202               20.174047    7.513461   14129.58566            NaN
# 240               21.909687    0.683504   34752.65849            NaN
# 264               31.311701    0.483355   48942.90715            NaN
# 300               33.521240    0.250000   49020.54389            NaN
# 336               32.981190   -0.202672   36317.66555            NaN
# 370               29.157036    0.148685   29740.83940            NaN
# 408               36.531628    0.356684   43378.17388            NaN
# 442               45.464314    0.700000   42622.16884            NaN
# 478               20.482416    0.394769   26700.75602            NaN
# 538               32.872040    1.696930   50109.98030            NaN
# 582               45.177593   -0.544936   37269.56584            NaN
# 620               15.286468   -0.094021   38370.45174            NaN
# 668               50.335358   -0.116667   42292.68131            NaN
# 702               50.269043    0.971675   36532.26382            NaN
# 730               42.995258    0.290833  102019.45830            NaN
# 760               24.061266    0.140631   25572.55882            NaN
# 794               36.032528    0.316667   50551.43754            NaN
# 828               23.412970   -0.664767   27057.65239            NaN
# 866               19.392345    0.607397   30606.48570            NaN
# 902               18.871790   -0.520010   30460.32019            NaN
# 938               24.278795   -0.055000   32729.60643            NaN
# 970               34.458351    0.984269   48904.55486            NaN
# 730                                           4.254260
# 760                                           4.451666
# 794                                           6.066433
# 828                                           5.227844
# 866                                           5.705128
# 902                                           4.667150
# 938                                           5.236783
# 970                                           5.969067
# 992                                           2.562744
#
#      Population ages 70-74 (as % of specified gender population)  \
# 44                                            3.624720
# 80                                            4.656064
# 116                                           3.723270
# 160                                           3.858605
# 202                                           1.702817
# 240                                           4.338560
# 264                                           4.800393
# 300                                           4.893083
# 336                                           4.108644
# 370                                           3.423183
# 408                                           4.661160
# 442                                           4.270581
# 478                                           3.867186
# 538                                           3.262323
# 582                                           2.389872
# 620                                           4.780811
# 668                                           5.973164
# 702                                           3.106637
# 730                                           3.084546
# 760                                           3.674426
# 794                                           4.409304
# 828                                           2.931801
# 866                                           4.639402
# 902                                           3.056619
# 938                                           4.010057
# 970                                           5.021237
# 992                                           1.881171
#
#      Population ages 75-79 (as % of specified gender population)  \
# 44                                            2.583086
# 80                                            3.445070
# 116                                           3.044227
# 160                                           2.604688
# 202                                           1.072841
# 240                                           2.500047
# 264                                           4.603274
# 300                                           3.170861
# 336                                           3.092914
# 370                                           2.868494
# 408                                           3.158252
# 442                                           3.148448
# 478                                           2.514788
# 538                                           2.208858
# 582                                           1.659548
# 620                                           4.176288
# 668                                           4.507184
# 702                                           2.246119
# 730                                           2.249530
# 760                                           3.033800
# 794                                           3.054506
# 828                                           2.242662
# 866                                           3.768393
# 902                                           1.898834
# 938                                           3.058620
# 970                                           3.311144
# 992                                           1.344584
#
#      Population ages 80 and older (as % of specified gender population)  \
# 44                                            3.306967
# 80                                            3.748363
# 116                                           4.137091
# 160                                           3.396353
# 202                                           1.116733
# 240                                           2.768844
# 264                                           4.406439
# 300                                           3.350950
# 336                                           4.634457
# 370                                           2.869145
# 408                                           3.675224
# 442                                           4.048929
# 478                                           2.571109
# 538                                           3.102834
# 582                                           2.393143
# 620                                           5.238151
# 668                                           5.649778
# 702                                           1.760207
# 730                                           2.973902
# 760                                           2.774941
# 794                                           3.347863
# 828                                           2.641769
# 866                                           4.645125
# 902                                           2.001157
# 938                                           3.262153
# 970                                           3.995259
# 992                                           1.105606
#
#      TER_Enrolment_rate  GNI per capita, Atlas method (current US$)  \
# 44                  NaN                                       54230
# 80                  NaN                                       45870
# 116                 NaN                                       41860
# 160                 NaN                                       43680
# 202                 NaN                                        6310
# 240                 NaN                                       17530
# 264                 NaN                                       43940
# 300                 NaN                                       57020
# 336                 NaN                                       27580
# 370                 NaN                                       17760
# 408                 NaN                                       45050
# 442                 NaN                                       42360
# 478                 NaN                                       12570
# 538                 NaN                                       56790
# 582                 NaN                                       36190
# 620                 NaN                                       31720
# 668                 NaN                                       37930
# 702                 NaN                                       27600
# 730                 NaN                                       71590
# 760                 NaN                                       14570
# 794                 NaN                                       46610
# 828                 NaN                                       12680
# 866                 NaN                                       19880
# 902                 NaN                                       16800
# 938                 NaN                                       21620
# 970                 NaN                                       54480
# 992                 NaN                                       11230
#
#      Quality_of_life_measure
# 44                  0.238984
# 80                  0.605279
# 116                 0.527435
# 160                 0.555110
# 202                 0.565752
# 240                 0.215580
# 264                 0.594008
# 300                 0.613960
# 336                 0.574799
# 370                 0.468353
# 408                 0.566063
# 442                 0.628968
# 478                 0.533436
# 538                 0.698189
# 582                 0.584567
# 620                 0.592382
# 668                 0.635714
# 702                 0.567652
# 730                 0.425305
# 760                 0.491563
# 794                 0.588412
# 828                 0.521128
# 866                 0.574330
# 902                 0.532642
# 938                 0.556128
# 970                 0.644115
# 992                 0.518578
#
# [27 rows x 41 columns]

# %%
df_gdp = df_male[['LOCATION','TIME','GDP_USD_CAP']]
df_gdp
# Out:
#      LOCATION  TIME  GDP_USD_CAP
# 0         AUS  1993  19929.78137
# 2         AUS  1994  21134.14664
# 4         AUS  1995  22098.57288
# 6         AUS  1997  24160.25514
# 8         AUS  1998  25342.18977
# 10        AUS  1999  26777.75563
# 12        AUS  2000  27888.22951
# 14        AUS  2001  29133.08851
# 16        AUS  2002  30376.85316
# 18        AUS  2003  31827.64206
# 20        AUS  2004  33454.90467
# 22        AUS  2005  35068.84566
# 24        AUS  2006  37138.28415
# 26        AUS  2007  38775.78024
# 28        AUS  2008  39219.47467
# 30        AUS  2009  40897.04122
# 32        AUS  2010  42165.82842
# 34        AUS  2011  43583.03701
# 36        AUS  2012  43082.38768
# 38        AUS  2013  47002.99005
# 40        AUS  2014  46920.61776
# 42        AUS  2015  46761.16774
# 44        AUS  2016  48177.78556
# 46        AUT  1999          NaN
# 48        AUT  2000          NaN
# 50        AUT  2001          NaN
# 52        AUT  2002          NaN
# 54        AUT  2003          NaN
# 56        AUT  2004  33765.56574
# 58        AUT  2005  35024.55748
# ...       ...   ...          ...
# 950       SWE  2006  37423.17798
# 952       SWE  2007  40572.72356
# 954       SWE  2008  41853.86487
# 956       SWE  2009  39645.72089
# 958       SWE  2010  41628.08825
# 960       SWE  2011  43755.12286
# 962       SWE  2012  44724.85125
# 964       SWE  2013  45673.07330
# 966       SWE  2014  46524.23047
# 968       SWE  2015  47891.20938
# 970       SWE  2016  48904.55486
# 972       TUR  2006  13497.95142
# 974       TUR  2007  14712.88468
# 976       TUR  2008  15901.07695
# 978       TUR  2009  15330.48081
# 980       TUR  2010  17281.32703
# 982       TUR  2011  19517.18146
# 984       TUR  2012  20549.29308
# 986       TUR  2013  22314.40367
# 988       TUR  2014  24158.80637
# 990       TUR  2015  25111.77646
# 992       TUR  2016  25655.47178
# 994       ZAF  2008  11778.88650
# 996       ZAF  2009  11516.41958
# 998       ZAF  2010  11833.73679
# 1000      ZAF  2011  12286.47410
# 1002      ZAF  2012  12592.84639
# 1004      ZAF  2013  12908.64390
# 1006      ZAF  2014  13148.75397
# 1008      ZAF  2015  13282.00987
#
# [505 rows x 3 columns]

# %%
# Get a list of the location names
locations = pd.Series({c: df_gdp[c].unique() for c in df_gdp})['LOCATION']
locations
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CHL', 'COL', 'CZE', 'DEU', 'DNK',
#        'ESP', 'EST', 'FIN', 'GBR', 'HUN', 'IRL', 'ISL', 'ISR', 'ITA',
#        'JPN', 'KOR', 'LUX', 'LVA', 'NLD', 'POL', 'PRT', 'SVK', 'SVN',
#        'SWE', 'TUR', 'ZAF'], dtype=object)

# %%
# Unfortunately because there are so many damn countries the line colours overlap
fig, ax = plt.subplots(1,1,figsize=(18, 16))
for key, grp in df_gdp.groupby(['LOCATION']): 
    ax.plot(grp['TIME'], grp['GDP_USD_CAP'], label = "GDP {}".format(key))
plt.legend(loc='best')    
plt.show()

# %% [markdown]
# ### Quality of Life timeseries comparison

# %%
fig, ax = plt.subplots(1,1,figsize=(18, 16))
for key, grp in df_male.groupby(['LOCATION']): 
    ax.plot(grp['TIME'], grp['Quality_of_life_measure'], label = "QoL {}".format(key))
plt.legend(loc='best')    
plt.show()

# %% [markdown]
# ### Correlation plot of GDP against QoL

# %%
# Seems pretty low, not sure if im doing it right tho
# Although I suppose GDP is not the only important factor so maybe not so unexpected
df_male['GDP_USD_CAP'].corr(df_male['Quality_of_life_measure'])
# Out:
# 0.28655817199114275

# %% [markdown]
# ## Linear Regression Analysis

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

#df_ML = df_male
#X = df_ML.drop(['LOCATION','id','TIME','GENDER','Quality_of_life_measure'],axis=1)
df_ML = df_male[['GDP_USD_CAP','Quality_of_life_measure']]
df_ML = df_ML.dropna(axis=0, how='any')
X = df_ML.drop(['Quality_of_life_measure'],axis=1).values.reshape(-1, 1)
Y = df_ML['Quality_of_life_measure'].values.reshape(-1, 1)
lm = linear_model.LinearRegression()
lm.fit(X,Y)

#pd.DataFrame(zip(X.columns, lm.coef_), columns = ['Features','Estimated Coeffs'])

fig, ax = plt.subplots(1,1,figsize=(18, 16))
ax.scatter(df_ML['GDP_USD_CAP'],Y)
plt.show()

# %% [markdown]
# Judging from the plot above it would be good to isolate the main cluster in the top left (i.e. get rid of some of the outliers). It's worth noticing that the gradients (ignoring the offset) all seem to have some correlation.

# %%
df_ML = df_male[['GDP_USD_CAP','Quality_of_life_measure']]
df_ML_no_outliers = df_ML.loc[(df_ML['GDP_USD_CAP'] < 60000) & (df_ML['Quality_of_life_measure'] > 0.3)]
df_ML = df_ML_no_outliers.dropna(axis=0, how='any')
X = df_ML_no_outliers.drop(['Quality_of_life_measure'],axis=1).values.reshape(-1, 1)
Y = df_ML_no_outliers['Quality_of_life_measure'].values.reshape(-1, 1)
lm = linear_model.LinearRegression()
lm.fit(X,Y)

#pd.DataFrame(zip(X.columns, lm.coef_), columns = ['Features','Estimated Coeffs'])

fig, ax = plt.subplots(1,1,figsize=(18, 16))
ax.scatter(df_ML_no_outliers['GDP_USD_CAP'],Y)
ax.plot(X, lm.predict(X),color='r')
plt.show()

# %% [markdown]
# Rought GDP to QoL linear regression fit, does indicate a good level of correlation. Although I feel like I should definitely remove the offsets from each country and just determine the best average gradient fit.

# %% [markdown]
# ### Linear regressions of multiple variables

# %%
list(df_male[['GDP_USD_CAP','EDU_TERTIARY_PC_WKGPOP','Quality_of_life_measure']].columns)
# Out:
# ['GDP_USD_CAP', 'EDU_TERTIARY_PC_WKGPOP', 'Quality_of_life_measure']

# %%
df_ML = df_male[['GDP_USD_CAP','EDU_TERTIARY_PC_WKGPOP','Quality_of_life_measure']]
df_ML = df_ML.dropna(axis=0, how='any')
x = df_ML.drop(['Quality_of_life_measure'],axis=1)
X = x.values.reshape(-1, 2)
Y = df_ML['Quality_of_life_measure'].values.reshape(-1, 1)
lm = linear_model.LinearRegression()
lm.fit(X,Y)

pd.DataFrame(list(zip(x.columns, lm.coef_[0])), columns = ['Features','Estimated Coeffs'])
# Out:
#                  Features  Estimated Coeffs
# 0             GDP_USD_CAP          0.000001
# 1  EDU_TERTIARY_PC_WKGPOP          0.002942

# %%
fig, ax = plt.subplots(1,1,figsize=(9, 8))
ax.scatter(df_ML['EDU_TERTIARY_PC_WKGPOP'],Y)
#ax.plot(X, lm.predict(X),color='r')
#plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
from string import ascii_letters
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
#rs = np.random.RandomState(33)
#d = pd.DataFrame(data=rs.normal(size=(100, 26)),
#                 columns=list(ascii_letters[26:]))
d=df_male.drop(['id'],axis=1)

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df_male.corr()['Quality_of_life_measure'].sort_values(ascending=False)
# Out:
# Quality_of_life_measure                                                                            1.000000
# Population ages 80 and older (as % of specified gender population)                                 0.407158
# Renewable electricity share of total electricity output (%) [4.1_SHARE.RE.IN.ELECTRICITY]          0.386403
# GNI per capita, Atlas method (current US$)                                                         0.365596
# EDU_TERTIARY_PC_WKGPOP                                                                             0.330615
# Population ages 75-79 (as % of specified gender population)                                        0.317034
# Population ages 65-69 (as % of specified gender population)                                        0.297664
# Population ages 70-74 (as % of specified gender population)                                        0.295127
# GDP_USD_CAP                                                                                        0.286558
# Renewable energy share of TFEC (%) [2.1_SHARE.TOTAL.RE.IN.TFEC]                                    0.270090
# Population ages 60-64 (as % of specified gender population)                                        0.267385
# %_Sanitation_Access                                                                                0.259194
# GOV_SPEND_EDU                                                                                      0.205059
# TIME                                                                                               0.199910
# Total final energy consumption (TFEC) (TJ) [1.1_TOTAL.FINAL.ENERGY.CONSUM]                         0.197788
# id                                                                                                 0.194857
# TER_Enrolment_rate                                                                                 0.194385
# Access to electricity (% of rural population with access) [1.2_ACCESS.ELECTRICITY.RURAL]           0.191889
# Total electricity output (GWh) [4.1.1_TOTAL.ELECTRICITY.OUTPUT]                                    0.189048
# Population ages 55-59 (as % of specified gender population)                                        0.187555
# Renewable electricity output (GWh) [4.1.2_REN.ELECTRICITY.OUTPUT]                                  0.184666
# Population (% of total)                                                                            0.159022
# Renewable energy consumption (TJ) [3.1_RE.CONSUMPTION]                                             0.143655
# Population ages 45-49 (as % of specified gender population)                                        0.134342
# Population ages 50-54 (as % of specified gender population)                                        0.121798
# Access to Clean Fuels and Technologies for cooking (% of total population) [2.1_ACCESS.CFT.TOT]    0.120129
# Access to electricity (% of total population) [1.1_ACCESS.ELECTRICITY.TOT]                         0.113267
# Population ages 40-44 (as % of specified gender population)                                        0.109502
# Population ages 35-39 (as % of specified gender population)                                       -0.070319
# Population ages 00-04 (as % of specified gender population)                                       -0.119524
# Population ages 05-09 (as % of specified gender population)                                       -0.144156
# Population ages 10-14 (as % of specified gender population)                                       -0.197165
# Energy intensity level of primary energy (MJ/2011 USD PPP) [6.1_PRIMARY.ENERGY.INTENSITY]         -0.197909
# CPI_AGRWTH                                                                                        -0.219658
# Population ages 15-19 (as % of specified gender population)                                       -0.254867
# Population ages 30-34 (as % of specified gender population)                                       -0.270189
# Population ages 20-24 (as % of specified gender population)                                       -0.345945
# Population ages 25-29 (as % of specified gender population)                                       -0.392311
# Name: Quality_of_life_measure, dtype: float64

# %% [markdown]
# So it would seem like the biggest drivers of QL are:
# * Life expectancy
# * % renewable energy (surprising)
# * GNI
# * Tertiary education
# * GDP
# * Sanitation
# * Gov spend on edu

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# Next step would be to train a proper ML classifier using each country as a new training example. We can feed in several key features such as GDP and education and try to refine weighting parameters. Then we can supplement with extra datasets. Probably split train:test data 80:20? Then once we're happy with the accuracy we can unleash it on the unclassified dataset.
